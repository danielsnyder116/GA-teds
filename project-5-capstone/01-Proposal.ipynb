# %% [markdown]
# # Data Science 5K Capstone Proposal
# In order to get your capstone approved, you must complete all of the following steps.

# %% [markdown]
# ## 1) Get your data
# You may use any data set(s) you like, so long as they meet these criteria:
#
# * Your data cannot have _anything_ to do with your work at Booz Allen Hamilton.
# * Your data must be publically available for free.
# * Your data should be interesting to _you_. You want your capstone to be something you're proud of.
# * Your data should be "big enough":
#     - It should have at least 1,000 rows.
#     - It should have enough of columns to be interesting.
#     - If you have questions, contact a member of the instructional team.

# %% [markdown]
# ## 2) Provide a link to your data
# Your data is required to be free and open to anyone. As such, you should have a URL which anyone can use to download your data:

# %% [markdown]
# https://www.kaggle.com/gbonesso/enem2015/home

# %% [markdown]
# Through this information, I found the source website so that I could download the most recent year data (2017):

# %% [markdown]
# http://portal.inep.gov.br/microdados

# %% [markdown]
# ## 3) Import your data
# In the space below, import your data. If your data span multiple files, read them all in. If applicable, merge or append them as needed.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 

# %matplotlib inline

# %%
# !pwd
# Out:
# /c/Users/602770/teds/PROJECT-5-CAPSTONE

# %%
path = "../enem2017/DADOS/MICRODADOS_ENEM_2017.csv"

# %%
enem = pd.read_csv(path, encoding="latin1", sep=";", low_memory=False)

# %%
enem.drop(["NU_ANO","CO_MUNICIPIO_RESIDENCIA","CO_UF_RESIDENCIA", "CO_MUNICIPIO_PROVA", "CO_UF_PROVA"], axis=1, inplace=True)

# %%
nordeste = enem.loc[enem["SG_UF_RESIDENCIA"].isin(["AL", "BA", "CE", "MA", "PB", "PE", "PI", "RN", "SE"]), :]

# %%
nordeste.to_csv("nordeste17.csv", encoding="latin1", index=False)

# %%
pd.set_option('max_rows', None)     
pd.set_option('max_columns', None)

# %%
pd.options.display.float_format = '{:.8f}'.format

# %% [markdown]
# ## 4) Show me the head of your data.

# %%
nordeste.head()
# Out:
#     NU_INSCRICAO  NO_MUNICIPIO_RESIDENCIA SG_UF_RESIDENCIA    NU_IDADE  \
# 4   170001663646                   Maceió               AL 40.00000000
# 9   170001669940  Jaboatão dos Guararapes               PE 23.00000000
# 11  170001668485                 Salvador               BA 26.00000000
# 13  170001665202                  Itarema               CE 24.00000000
# 14  170001665203                Fortaleza               CE 24.00000000
#
#    TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  TP_NACIONALIDADE  \
# 4        M       0.00000000            3                 1
# 9        M       0.00000000            3                 1
# 11       F       0.00000000            0                 1
# 13       M       0.00000000            1                 1
# 14       M       0.00000000            2                 1
#
#     CO_MUNICIPIO_NASCIMENTO  NO_MUNICIPIO_NASCIMENTO  CO_UF_NASCIMENTO  \
# 4          2704302.00000000                   Maceió       27.00000000
# 9          2607901.00000000  Jaboatão dos Guararapes       26.00000000
# 11         2927408.00000000                 Salvador       29.00000000
# 13         2307650.00000000                Maracanaú       23.00000000
# 14         2304400.00000000                Fortaleza       23.00000000
#
#    SG_UF_NASCIMENTO  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  TP_ENSINO  \
# 4                AL                1               11          1        nan
# 9                PE                1                3          1        nan
# 11               BA                1                7          1        nan
# 13               CE                1                7          1        nan
# 14               CE                1                3          1        nan
#
#     IN_TREINEIRO  CO_ESCOLA  CO_MUNICIPIO_ESC NO_MUNICIPIO_ESC  CO_UF_ESC  \
# 4              0        nan               nan              NaN        nan
# 9              0        nan               nan              NaN        nan
# 11             0        nan               nan              NaN        nan
# 13             0        nan               nan              NaN        nan
# 14             0        nan               nan              NaN        nan
#
#    SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  TP_LOCALIZACAO_ESC  TP_SIT_FUNC_ESC  \
# 4        NaN                     nan                 nan              nan
# 9        NaN                     nan                 nan              nan
# 11       NaN                     nan                 nan              nan
# 13       NaN                     nan                 nan              nan
# 14       NaN                     nan                 nan              nan
#
#     IN_BAIXA_VISAO  IN_CEGUEIRA  IN_SURDEZ  IN_DEFICIENCIA_AUDITIVA  \
# 4                0            0          0                        0
# 9                0            0          0                        0
# 11               0            0          0                        0
# 13               0            0          0                        0
# 14               0            0          0                        0
#
#     IN_SURDO_CEGUEIRA  IN_DEFICIENCIA_FISICA  IN_DEFICIENCIA_MENTAL  \
# 4                   0                      0                      0
# 9                   0                      0                      0
# 11                  0                      0                      0
# 13                  0                      0                      0
# 14                  0                      0                      0
#
#     IN_DEFICIT_ATENCAO  IN_DISLEXIA  IN_DISCALCULIA  IN_AUTISMO  \
# 4                    0            0               0           0
# 9                    0            0               0           0
# 11                   0            0               0           0
# 13                   0            0               0           0
# 14                   0            0               0           0
#
#     IN_VISAO_MONOCULAR  IN_OUTRA_DEF  IN_GESTANTE  IN_LACTANTE  IN_IDOSO  \
# 4                    0             0            0            0         0
# 9                    0             0            0            0         0
# 11                   0             0            0            0         0
# 13                   0             0            0            0         0
# 14                   0             0            0            0         0
#
#     IN_ESTUDA_CLASSE_HOSPITALAR  IN_SEM_RECURSO  IN_BRAILLE  IN_AMPLIADA_24  \
# 4                             0               0           0               0
# 9                             0               0           0               0
# 11                            0               0           0               0
# 13                            0               0           0               0
# 14                            0               0           0               0
#
#     IN_AMPLIADA_18  IN_LEDOR  IN_ACESSO  IN_TRANSCRICAO  IN_LIBRAS  \
# 4                0         0          0               0          0
# 9                0         0          0               0          0
# 11               0         0          0               0          0
# 13               0         0          0               0          0
# 14               0         0          0               0          0
#
#     IN_LEITURA_LABIAL  IN_MESA_CADEIRA_RODAS  IN_MESA_CADEIRA_SEPARADA  \
# 4                   0                      0                         0
# 9                   0                      0                         0
# 11                  0                      0                         0
# 13                  0                      0                         0
# 14                  0                      0                         0
#
#     IN_APOIO_PERNA  IN_GUIA_INTERPRETE  IN_COMPUTADOR  IN_CADEIRA_ESPECIAL  \
# 4                0                   0              0                    0
# 9                0                   0              0                    0
# 11               0                   0              0                    0
# 13               0                   0              0                    0
# 14               0                   0              0                    0
#
#     IN_CADEIRA_CANHOTO  IN_CADEIRA_ACOLCHOADA  IN_PROVA_DEITADO  \
# 4                    0                      0                 0
# 9                    0                      0                 0
# 11                   0                      0                 0
# 13                   0                      0                 0
# 14                   0                      0                 0
#
#     IN_MOBILIARIO_OBESO  IN_LAMINA_OVERLAY  IN_PROTETOR_AURICULAR  \
# 4                     0                  0                      0
# 9                     0                  0                      0
# 11                    0                  0                      0
# 13                    0                  0                      0
# 14                    0                  0                      0
#
#     IN_MEDIDOR_GLICOSE  IN_MAQUINA_BRAILE  IN_SOROBAN  IN_MARCA_PASSO  \
# 4                    0                  0           0               0
# 9                    0                  0           0               0
# 11                   0                  0           0               0
# 13                   0                  0           0               0
# 14                   0                  0           0               0
#
#     IN_SONDA  IN_MEDICAMENTOS  IN_SALA_INDIVIDUAL  IN_SALA_ESPECIAL  \
# 4          0                0                   0                 0
# 9          0                0                   0                 0
# 11         0                0                   0                 0
# 13         0                0                   0                 0
# 14         0                0                   0                 0
#
#     IN_SALA_ACOMPANHANTE  IN_MOBILIARIO_ESPECIFICO  IN_MATERIAL_ESPECIFICO  \
# 4                      0                         0                       0
# 9                      0                         0                       0
# 11                     0                         0                       0
# 13                     0                         0                       0
# 14                     0                         0                       0
#
#     IN_NOME_SOCIAL       NO_MUNICIPIO_PROVA SG_UF_PROVA  TP_PRESENCA_CN  \
# 4                0                   Maceió          AL      1.00000000
# 9                0  Jaboatão dos Guararapes          PE      1.00000000
# 11               0                 Salvador          BA      1.00000000
# 13               0                  Itarema          CE      1.00000000
# 14               0                Fortaleza          CE      1.00000000
#
#     TP_PRESENCA_CH  TP_PRESENCA_LC  TP_PRESENCA_MT  CO_PROVA_CN  CO_PROVA_CH  \
# 4       1.00000000      1.00000000      1.00000000 392.00000000 395.00000000
# 9       1.00000000      1.00000000      1.00000000 391.00000000 396.00000000
# 11      1.00000000      1.00000000      1.00000000 392.00000000 396.00000000
# 13      1.00000000      1.00000000      1.00000000 391.00000000 397.00000000
# 14      1.00000000      1.00000000      1.00000000 392.00000000 395.00000000
#
#     CO_PROVA_LC  CO_PROVA_MT   NU_NOTA_CN   NU_NOTA_CH   NU_NOTA_LC  \
# 4  399.00000000 404.00000000 482.10000000 569.20000000 570.80000000
# 9  400.00000000 403.00000000 533.80000000 427.60000000 320.70000000
# 11 400.00000000 404.00000000 613.20000000 616.70000000 623.10000000
# 13 402.00000000 403.00000000 501.80000000 566.60000000 544.90000000
# 14 399.00000000 404.00000000 462.50000000 523.60000000 571.50000000
#
#      NU_NOTA_MT                                TX_RESPOSTAS_CN  \
# 4  584.60000000  EAAAAAEEEABCDEABDDBAEDDDBBDBCAEEBEEBCACBACBEE
# 9  479.00000000  BDEAEBDADAEEBCBDABADCECCACEADBDBBCACEAAACAABC
# 11 656.50000000  DDEBBEACEADDDCADEBDACDBECBEDABBDBEAEBAEDECCDE
# 13 645.10000000  BACEADBACDEDDABECECDBABCAAEDBDCBBDCCACEDAABDD
# 14 517.60000000  ACCBAAECEECBEAABDCAEDDDCDABBBCAADBCACACABCBCD
#
#                                   TX_RESPOSTAS_CH  \
# 4   EDCEAABBECBDBDADDDADCAEEEDEBBEEEACADAEAACECBA
# 9   CABDABBCEDBACCBACADBACBACBDACABCEADBECAEBADEB
# 11  DACAEDCDDCDBEEBACCEBBBDCDBBEDEDBEDBDAADECDBEC
# 13  ACDEBBDCECCDBACBEAAEBCDBBDCEDECAEDCEBECAABDCA
# 14  ECDDCAAEEABABBEAABAADCBEBABEBCDCCBAEABBCADBEA
#
#                                       TX_RESPOSTAS_LC  \
# 4   EDBED99999BADEDEABCCBDCEAEDEEBEBBBDEADBEEAADAE...
# 9   CBAED99999AACDDACDECACACDADBDBDBDACCEBADBADCDA...
# 11  EDDCD99999BCEADCEDAEDAADEDBEADADEDDBCAADEDCBEA...
# 13  99999CDBDCBEEAEADEADCDBACABEEEADAADBCACBEDEAAB...
# 14  DDBEE99999BEDDCAABCDCDAECADEBEEBDCCEAEBDEABCAC...
#
#                                   TX_RESPOSTAS_MT  TP_LINGUA  \
# 4   CACBDEACECECEECDDBBBDBABCDBCCEEDBBCCDDCCDACED          0
# 9   BCBDABCDEBEBADECDCAABCEEBDEBDBDCEBACADCDBEABA          0
# 11  AECCCEBCDBABDDADBADBEEABBECDCEDEEBBCACEAEBCBD          0
# 13  EBACEACCDABEBBBDDDABBCEDCDDDDCCBCBEEDBEABADBD          1
# 14  AACACADDBECBECDEEDBBACACBBBCADDCCACBDEBBABCBD          0
#
#                                    TX_GABARITO_CN  \
# 4   BCBBEBAAEDDCBDADEEBADECDCBCDAAEABCEEAAECDCCDA
# 9   DEEBDABCBBEDDCBABCADECEBAADAAECDCBCCDACDEEAAE
# 11  BCBBEBAAEDDCBDADEEBADECDCBCDAAEABCEEAAECDCCDA
# 13  DEEBDABCBBEDDCBABCADECEBAADAAECDCBCCDACDEEAAE
# 14  BCBBEBAAEDDCBDADEEBADECDCBCDAAEABCEEAAECDCCDA
#
#                                    TX_GABARITO_CH  \
# 4   CDDECADBEABDBEDAECAEBDAEBAEDBDBBAECDAEBCCCCDE
# 9   CDEAEECAEBDBDBBAECDAEBCCCDAEBEABDBEDAADBCDDEC
# 11  CDEAEECAEBDBDBBAECDAEBCCCDAEBEABDBEDAADBCDDEC
# 13  ECAEBCDDECADBEABDDBDBDAEBCCCCDEAEDAEBBEDABAEC
# 14  CDDECADBEABDBEDAECAEBDAEBAEDBDBBAECDAEBCCCCDE
#
#                                        TX_GABARITO_LC  \
# 4   DDCDEEDBEEBDAEDAABCECDAEBADEDEDBBBDEABBCCABAAE...
# 9   EDDCDBEEDECCEBDAEDAEDAABEDBBADEDEDDABAABBDCBEA...
# 11  EDDCDBEEDECCEBDAEDAEDAABEDBBADEDEDDABAABBDCBEA...
# 13  DDCDEEDBEECEBADEDEABEDBBBDBCCABAAAABCBDAEDEDDB...
# 14  DDCDEEDBEEBDAEDAABCECDAEBADEDEDBBBDEABBCCABAAE...
#
#                                    TX_GABARITO_MT  TP_STATUS_REDACAO  \
# 4   CCECEECDADBBDBBDBAEBDDABECBDCCDEDBBACAEADAEAC         1.00000000
# 9   ADBCCECBBDBAEBBDDDABDCCDEDECBEACDAEAABBACEECD         1.00000000
# 11  CCECEECDADBBDBBDBAEBDDABECBDCCDEDBBACAEADAEAC         1.00000000
# 13  ADBCCECBBDBAEBBDDDABDCCDEDECBEACDAEAABBACEECD         1.00000000
# 14  CCECEECDADBBDBBDBAEBDDABECBDCCDEDBBACAEADAEAC         1.00000000
#
#     NU_NOTA_COMP1  NU_NOTA_COMP2  NU_NOTA_COMP3  NU_NOTA_COMP4  NU_NOTA_COMP5  \
# 4    140.00000000   120.00000000   120.00000000   120.00000000    80.00000000
# 9     80.00000000   100.00000000    80.00000000    60.00000000     0.00000000
# 11   140.00000000   120.00000000   120.00000000   120.00000000    60.00000000
# 13   160.00000000   120.00000000   120.00000000   120.00000000   100.00000000
# 14   160.00000000   120.00000000   120.00000000   140.00000000    80.00000000
#
#     NU_NOTA_REDACAO Q001 Q002 Q003 Q004       Q005 Q006 Q007 Q008 Q009 Q010  \
# 4      580.00000000    A    B    B    F 3.00000000    C    A    B    B    A
# 9      320.00000000    A    E    A    A 3.00000000    B    B    B    C    A
# 11     560.00000000    G    F    D    B 6.00000000    J    A    D    D    B
# 13     620.00000000    B    E    A    F 5.00000000    E    A    C    D    A
# 14     620.00000000    B    B    C    B 5.00000000    C    A    B    B    A
#
#    Q011 Q012 Q013 Q014 Q015 Q016 Q017 Q018 Q019 Q020 Q021 Q022 Q023 Q024 Q025  \
# 4     B    B    A    A    A    A    A    A    B    B    A    C    A    C    B
# 9     A    B    A    B    A    B    A    A    B    B    A    D    B    B    B
# 11    B    B    B    B    B    B    A    A    D    A    B    E    B    E    B
# 13    B    B    A    A    A    A    A    A    C    A    A    E    B    B    B
# 14    A    B    A    A    A    A    A    A    B    A    A    A    A    B    B
#
#    Q026 Q027
# 4     A    A
# 9     A    A
# 11    A    D
# 13    A    A
# 14    A    A

# %% [markdown]
# ## 5) Show me the shape of your data

# %%
nordeste.shape
# Out:
# (2223044, 132)

# %% [markdown]
# ## 6) Show me the proportion of missing observations for each column of your data

# %%
nordeste.isnull().mean()
# Out:
# NU_INSCRICAO                  0.00000000
# NO_MUNICIPIO_RESIDENCIA       0.00000000
# SG_UF_RESIDENCIA              0.00000000
# NU_IDADE                      0.00001170
# TP_SEXO                       0.00000000
# TP_ESTADO_CIVIL               0.03730201
# TP_COR_RACA                   0.00000000
# TP_NACIONALIDADE              0.00000000
# CO_MUNICIPIO_NASCIMENTO       0.03655438
# NO_MUNICIPIO_NASCIMENTO       0.03655438
# CO_UF_NASCIMENTO              0.03655438
# SG_UF_NASCIMENTO              0.03655438
# TP_ST_CONCLUSAO               0.00000000
# TP_ANO_CONCLUIU               0.00000000
# TP_ESCOLA                     0.00000000
# TP_ENSINO                     0.77158707
# IN_TREINEIRO                  0.00000000
# CO_ESCOLA                     0.77158527
# CO_MUNICIPIO_ESC              0.77158842
# NO_MUNICIPIO_ESC              0.77158842
# CO_UF_ESC                     0.77158842
# SG_UF_ESC                     0.77158842
# TP_DEPENDENCIA_ADM_ESC        0.77158842
# TP_LOCALIZACAO_ESC            0.77158842
# TP_SIT_FUNC_ESC               0.77215431
# IN_BAIXA_VISAO                0.00000000
# IN_CEGUEIRA                   0.00000000
# IN_SURDEZ                     0.00000000
# IN_DEFICIENCIA_AUDITIVA       0.00000000
# IN_SURDO_CEGUEIRA             0.00000000
# IN_DEFICIENCIA_FISICA         0.00000000
# IN_DEFICIENCIA_MENTAL         0.00000000
# IN_DEFICIT_ATENCAO            0.00000000
# IN_DISLEXIA                   0.00000000
# IN_DISCALCULIA                0.00000000
# IN_AUTISMO                    0.00000000
# IN_VISAO_MONOCULAR            0.00000000
# IN_OUTRA_DEF                  0.00000000
# IN_GESTANTE                   0.00000000
# IN_LACTANTE                   0.00000000
# IN_IDOSO                      0.00000000
# IN_ESTUDA_CLASSE_HOSPITALAR   0.00000000
# IN_SEM_RECURSO                0.00000000
# IN_BRAILLE                    0.00000000
# IN_AMPLIADA_24                0.00000000
# IN_AMPLIADA_18                0.00000000
# IN_LEDOR                      0.00000000
# IN_ACESSO                     0.00000000
# IN_TRANSCRICAO                0.00000000
# IN_LIBRAS                     0.00000000
# IN_LEITURA_LABIAL             0.00000000
# IN_MESA_CADEIRA_RODAS         0.00000000
# IN_MESA_CADEIRA_SEPARADA      0.00000000
# IN_APOIO_PERNA                0.00000000
# IN_GUIA_INTERPRETE            0.00000000
# IN_COMPUTADOR                 0.00000000
# IN_CADEIRA_ESPECIAL           0.00000000
# IN_CADEIRA_CANHOTO            0.00000000
# IN_CADEIRA_ACOLCHOADA         0.00000000
# IN_PROVA_DEITADO              0.00000000
# IN_MOBILIARIO_OBESO           0.00000000
# IN_LAMINA_OVERLAY             0.00000000
# IN_PROTETOR_AURICULAR         0.00000000
# IN_MEDIDOR_GLICOSE            0.00000000
# IN_MAQUINA_BRAILE             0.00000000
# IN_SOROBAN                    0.00000000
# IN_MARCA_PASSO                0.00000000
# IN_SONDA                      0.00000000
# IN_MEDICAMENTOS               0.00000000
# IN_SALA_INDIVIDUAL            0.00000000
# IN_SALA_ESPECIAL              0.00000000
# IN_SALA_ACOMPANHANTE          0.00000000
# IN_MOBILIARIO_ESPECIFICO      0.00000000
# IN_MATERIAL_ESPECIFICO        0.00000000
# IN_NOME_SOCIAL                0.00000000
# NO_MUNICIPIO_PROVA            0.00000000
# SG_UF_PROVA                   0.00000000
# TP_PRESENCA_CN                0.00002069
# TP_PRESENCA_CH                0.00002069
# TP_PRESENCA_LC                0.00002069
# TP_PRESENCA_MT                0.00002069
# CO_PROVA_CN                   0.32159462
# CO_PROVA_CH                   0.28744010
# CO_PROVA_LC                   0.28744010
# CO_PROVA_MT                   0.32159462
# NU_NOTA_CN                    0.32159462
# NU_NOTA_CH                    0.28744010
# NU_NOTA_LC                    0.28744010
# NU_NOTA_MT                    0.32159462
# TX_RESPOSTAS_CN               0.32159462
# TX_RESPOSTAS_CH               0.28744010
# TX_RESPOSTAS_LC               0.28744010
# TX_RESPOSTAS_MT               0.32159462
# TP_LINGUA                     0.00000000
# TX_GABARITO_CN                0.32159462
# TX_GABARITO_CH                0.28744010
# TX_GABARITO_LC                0.28744010
# TX_GABARITO_MT                0.32159462
# TP_STATUS_REDACAO             0.28744010
# NU_NOTA_COMP1                 0.28744010
# NU_NOTA_COMP2                 0.28744010
# NU_NOTA_COMP3                 0.28744010
# NU_NOTA_COMP4                 0.28744010
# NU_NOTA_COMP5                 0.28744010
# NU_NOTA_REDACAO               0.28744010
# Q001                          0.00000000
# Q002                          0.00000000
# Q003                          0.00000045
# Q004                          0.00000045
# Q005                          0.00000045
# Q006                          0.00000045
# Q007                          0.00000045
# Q008                          0.00000045
# Q009                          0.00000045
# Q010                          0.00000045
# Q011                          0.00000045
# Q012                          0.00000045
# Q013                          0.00000045
# Q014                          0.00000045
# Q015                          0.00000045
# Q016                          0.00000045
# Q017                          0.00000045
# Q018                          0.00000045
# Q019                          0.00000045
# Q020                          0.00000045
# Q021                          0.00000045
# Q022                          0.00000045
# Q023                          0.00000045
# Q024                          0.00000045
# Q025                          0.00000045
# Q026                          0.00000045
# Q027                          0.00000045
# dtype: float64

# %% [markdown]
# ## 7) Give me a problem statement.
# Below, write a problem statement. Keep in mind that your task is to tease out relationships in your data and eventually build a predictive model. Your problem statement can be vague, but you should have a goal in mind. Your problem statement should be between one sentence and one paragraph.

# %% [markdown]
# _Brazil's traditional college entrance exam, the "Vestibular", has been criticized for giving an unfair advantage to wealthy, private students, and in 1998, a new exam, "ENEM", was created. In 2009, a revised format known as the "New ENEM" was initiated with the goal of democratizing access to higher education.Our task is to help the federal government analyze the 2017 exam results to find any trends regarding the demographics of students who took the exam (among other factors: age, race, sex, marital status, disability status, income, education type, state, region, etc.). Through this data, we will develop a predictive model to see how influential demographic factors are in accurately predicting scores. This information may be useful in guiding future government actions to more precisely support students who may be disadvantaged._

# %% [markdown]
# ## 8) What is your _y_-variable?
# For Part C of your capstone, you will need to perform a statistical model. This means you will have to accurately predict some y-variable for some combination of x-variables. From your problem statement in part 7, what is that y-variable?

# %% [markdown]
# My y-variable is the predicted exam score for a student based on various attributes (x-variables).
